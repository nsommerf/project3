# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Read in CSVs
crimes_2019 = pd.read_csv("crimes2019.csv")
crimes_2020 = pd.read_csv("crimes2020.csv")
crimes_2021 = pd.read_csv("crimes2021.csv")

# %%
# Concatenate crime csv files
crime_data = pd.concat([crimes_2019,crimes_2020,crimes_2021])

# %%
# Preview full crime data
crime_data.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11864018    JC476123  09/24/2019 08:00:00 AM  022XX S MICHIGAN AVE  1154
# 1  11859805    JC471592  10/13/2019 08:30:00 PM   024XX W CHICAGO AVE  0860
# 2  11863808    JC476236  10/05/2019 06:30:00 PM     0000X N LOOMIS ST  0810
# 3  11859727    JC471542  10/13/2019 07:00:00 PM    016XX W ADDISON ST  1320
# 4  11859656    JC471240  10/13/2019 02:10:00 PM      051XX N BROADWAY  0560
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 1               THEFT                             RETAIL THEFT
# 2               THEFT                                OVER $500
# 3     CRIMINAL DAMAGE                               TO VEHICLE
# 4             ASSAULT                                   SIMPLE
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0  COMMERCIAL / BUSINESS OFFICE   False     False  ...   3.0            33.0
# 1            GROCERY FOOD STORE   False     False  ...  26.0            24.0
# 2                     RESIDENCE   False     False  ...  27.0            28.0
# 3                        STREET   False     False  ...  47.0             6.0
# 4                   GAS STATION   False     False  ...  47.0             3.0
#
#    FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0        11     1177560.0    1889548.0  2019  10/20/2019 03:56:02 PM
# 1        06     1160005.0    1905256.0  2019  10/20/2019 04:03:03 PM
# 2        06     1166986.0    1900306.0  2019  10/20/2019 03:56:02 PM
# 3        14     1164930.0    1923972.0  2019  10/20/2019 04:03:03 PM
# 4       08A     1167380.0    1934505.0  2019  10/20/2019 04:03:03 PM
#
#     Latitude  Longitude                       Location
# 0  41.852248 -87.623786  (41.852248185, -87.623786256)
# 1  41.895732 -87.687784  (41.895732399, -87.687784384)
# 2  41.882002 -87.662287   (41.88200224, -87.662286977)
# 3  41.946987 -87.669164  (41.946987144, -87.669163602)
# 4  41.975838 -87.659854  (41.975837637, -87.659853835)
#
# [5 rows x 22 columns]

# %%
crime_data.groupby("Primary Type").count()
crime_data_clean = crime_data.loc[~crime_data["Primary Type"].isin(crime_data), :]
crime_data_clean['Primary Type'].value_counts()
# Out:
# THEFT                                115000
# BATTERY                              103838
# CRIMINAL DAMAGE                       59479
# ASSAULT                               45277
# DECEPTIVE PRACTICE                    43048
# OTHER OFFENSE                         34036
# NARCOTICS                             24325
# MOTOR VEHICLE THEFT                   22187
# BURGLARY                              20217
# ROBBERY                               18256
# WEAPONS VIOLATION                     17766
# CRIMINAL TRESPASS                     12107
# OFFENSE INVOLVING CHILDREN             4916
# PUBLIC PEACE VIOLATION                 2975
# SEX OFFENSE                            2570
# INTERFERENCE WITH PUBLIC OFFICER       2319
# CRIMINAL SEXUAL ASSAULT                2239
# HOMICIDE                               1503
# ARSON                                  1124
# CRIM SEXUAL ASSAULT                    1003
# PROSTITUTION                            972
# STALKING                                532
# CONCEALED CARRY LICENSE VIOLATION       425
# LIQUOR LAW VIOLATION                    419
# INTIMIDATION                            367
# KIDNAPPING                              326
# GAMBLING                                170
# OBSCENITY                               136
# HUMAN TRAFFICKING                        22
# PUBLIC INDECENCY                         22
# OTHER NARCOTIC VIOLATION                 15
# NON-CRIMINAL                              7
# RITUALISM                                 1
# Name: Primary Type, dtype: int64

# %%
from datetime import datetime,date

# %%
crime_data_cleaner = crime_data_clean[['ID', 'Primary Type', 'Date','Description', 'Location Description', 'Arrest', 'Domestic', 'Community Area', 'Year', 'Latitude', 'Longitude', 'Location']]

crime_data_cleaner.head()
# Out:
#          ID        Primary Type                    Date  \
# 0  11864018  DECEPTIVE PRACTICE  09/24/2019 08:00:00 AM
# 1  11859805               THEFT  10/13/2019 08:30:00 PM
# 2  11863808               THEFT  10/05/2019 06:30:00 PM
# 3  11859727     CRIMINAL DAMAGE  10/13/2019 07:00:00 PM
# 4  11859656             ASSAULT  10/13/2019 02:10:00 PM
#
#                                Description          Location Description  \
# 0  FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                             RETAIL THEFT            GROCERY FOOD STORE
# 2                                OVER $500                     RESIDENCE
# 3                               TO VEHICLE                        STREET
# 4                                   SIMPLE                   GAS STATION
#
#    Arrest  Domestic  Community Area  Year   Latitude  Longitude  \
# 0   False     False            33.0  2019  41.852248 -87.623786
# 1   False     False            24.0  2019  41.895732 -87.687784
# 2   False     False            28.0  2019  41.882002 -87.662287
# 3   False     False             6.0  2019  41.946987 -87.669164
# 4   False     False             3.0  2019  41.975838 -87.659854
#
#                         Location
# 0  (41.852248185, -87.623786256)
# 1  (41.895732399, -87.687784384)
# 2   (41.88200224, -87.662286977)
# 3  (41.946987144, -87.669163602)
# 4  (41.975837637, -87.659853835)

# %%
#change column names 
#drop nulls
#save df into csv OR connect from jupyter notebook

crime_data_cleaner.dropna()
crime_data_cleaner.columns=["id","primary_type","date","description", "location_description","arrest","domestic","community_area", "year", "lat" , "lng", "location"]
crime_data_cleaner.head()
# Out:
#          id        primary_type                    date  \
# 0  11864018  DECEPTIVE PRACTICE  09/24/2019 08:00:00 AM
# 1  11859805               THEFT  10/13/2019 08:30:00 PM
# 2  11863808               THEFT  10/05/2019 06:30:00 PM
# 3  11859727     CRIMINAL DAMAGE  10/13/2019 07:00:00 PM
# 4  11859656             ASSAULT  10/13/2019 02:10:00 PM
#
#                                description          location_description  \
# 0  FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                             RETAIL THEFT            GROCERY FOOD STORE
# 2                                OVER $500                     RESIDENCE
# 3                               TO VEHICLE                        STREET
# 4                                   SIMPLE                   GAS STATION
#
#    arrest  domestic  community_area  year        lat        lng  \
# 0   False     False            33.0  2019  41.852248 -87.623786
# 1   False     False            24.0  2019  41.895732 -87.687784
# 2   False     False            28.0  2019  41.882002 -87.662287
# 3   False     False             6.0  2019  41.946987 -87.669164
# 4   False     False             3.0  2019  41.975838 -87.659854
#
#                         location
# 0  (41.852248185, -87.623786256)
# 1  (41.895732399, -87.687784384)
# 2   (41.88200224, -87.662286977)
# 3  (41.946987144, -87.669163602)
# 4  (41.975837637, -87.659853835)

# %%
crime_data_cleaner.dtypes
# Out:
# id                        int64
# primary_type             object
# date                     object
# description              object
# location_description     object
# arrest                     bool
# domestic                   bool
# community_area          float64
# year                      int64
# lat                     float64
# lng                     float64
# location                 object
# dtype: object

# %%
crime_data_cleaner['date']= pd.to_datetime(crime_data_cleaner["date"])
crime_data_cleaner.head()
# Out:
# <ipython-input-10-b756ba49e938>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_data_cleaner['date']= pd.to_datetime(crime_data_cleaner["date"])
#          id        primary_type                date  \
# 0  11864018  DECEPTIVE PRACTICE 2019-09-24 08:00:00
# 1  11859805               THEFT 2019-10-13 20:30:00
# 2  11863808               THEFT 2019-10-05 18:30:00
# 3  11859727     CRIMINAL DAMAGE 2019-10-13 19:00:00
# 4  11859656             ASSAULT 2019-10-13 14:10:00
#
#                                description          location_description  \
# 0  FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                             RETAIL THEFT            GROCERY FOOD STORE
# 2                                OVER $500                     RESIDENCE
# 3                               TO VEHICLE                        STREET
# 4                                   SIMPLE                   GAS STATION
#
#    arrest  domestic  community_area  year        lat        lng  \
# 0   False     False            33.0  2019  41.852248 -87.623786
# 1   False     False            24.0  2019  41.895732 -87.687784
# 2   False     False            28.0  2019  41.882002 -87.662287
# 3   False     False             6.0  2019  41.946987 -87.669164
# 4   False     False             3.0  2019  41.975838 -87.659854
#
#                         location
# 0  (41.852248185, -87.623786256)
# 1  (41.895732399, -87.687784384)
# 2   (41.88200224, -87.662286977)
# 3  (41.946987144, -87.669163602)
# 4  (41.975837637, -87.659853835)

# %%
crime_data_cleaner['date']= crime_data_cleaner['date'].dt.strftime("%Y-%m-%d")
crime_data_cleaner.head()
# Out:
# <ipython-input-11-278bcf39c742>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_data_cleaner['date']= crime_data_cleaner['date'].dt.strftime("%Y-%m-%d")
#          id        primary_type        date  \
# 0  11864018  DECEPTIVE PRACTICE  2019-09-24
# 1  11859805               THEFT  2019-10-13
# 2  11863808               THEFT  2019-10-05
# 3  11859727     CRIMINAL DAMAGE  2019-10-13
# 4  11859656             ASSAULT  2019-10-13
#
#                                description          location_description  \
# 0  FINANCIAL IDENTITY THEFT $300 AND UNDER  COMMERCIAL / BUSINESS OFFICE
# 1                             RETAIL THEFT            GROCERY FOOD STORE
# 2                                OVER $500                     RESIDENCE
# 3                               TO VEHICLE                        STREET
# 4                                   SIMPLE                   GAS STATION
#
#    arrest  domestic  community_area  year        lat        lng  \
# 0   False     False            33.0  2019  41.852248 -87.623786
# 1   False     False            24.0  2019  41.895732 -87.687784
# 2   False     False            28.0  2019  41.882002 -87.662287
# 3   False     False             6.0  2019  41.946987 -87.669164
# 4   False     False             3.0  2019  41.975838 -87.659854
#
#                         location
# 0  (41.852248185, -87.623786256)
# 1  (41.895732399, -87.687784384)
# 2   (41.88200224, -87.662286977)
# 3  (41.946987144, -87.669163602)
# 4  (41.975837637, -87.659853835)

# %%
crime_data_cleaner.to_csv("clean_crimedata.csv", index=False)

# %%
engine = create_engine("sqlite:///crime_db.sqlite")

# %%
crime_data_cleaner.to_sql('crimes', engine)
